# %%
from pyspark import SparkContext

# %%
sc = SparkContext('local', 'EndSemWeek1')
# Out:
# 25/10/26 19:30:49 WARN SparkContext: Another SparkContext is being constructed (or threw an exception in its constructor). This may indicate an error, since only one SparkContext should be running in this JVM (see SPARK-2243). The other SparkContext was created at:
# org.apache.spark.api.java.JavaSparkContext.<init>(JavaSparkContext.scala:59)
# java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:77)
# java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:500)
# java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:481)
# py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# ...

# %%
arr = sc.parallelize([1, 2, 3, 4, 5, 6])

# %%
arr = arr.map(lambda x: x**2)

# %%
arr.collect()
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
arr.max()
# Out:
# 36

# %%
arr.mean()
# Out:
# 15.166666666666668

# %%
sc.stop()

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('EndSem1').getOrCreate()

# %%
df = spark.read.csv('file:///home/karthikeya/Desktop/sem5/MIT_SEM5_BDA/Week1/MOCK_DATA.csv', header=True, inferSchema=True)

# %%
df.show(5)
# Out:
# +---+----------+----------+--------------------+-----------+---------------+
# | id|first_name| last_name|               email|     gender|     ip_address|
# +---+----------+----------+--------------------+-----------+---------------+
# |  1|     Ossie|   Lamborn|olamborn0@chicago...|       Male|    50.26.66.51|
# |  2|     Tonya|   Hazzard|thazzard1@canalbl...|     Female|130.135.190.120|
# |  3|     Jenni|Sedgefield|jsedgefield2@ramb...|Genderqueer|  23.100.91.208|
# |  4| Heriberto|   Lydford|hlydford3@reddit.com|       Male|  38.193.109.78|
# |  5|   Chaddie|    Haxbie|chaxbie4@creative...|       Male|145.192.132.186|
# +---+----------+----------+--------------------+-----------+---------------+
# only showing top 5 rows

# %%
df.agg({'id':'mean'}).show()
# Out:
# +-------+
# |avg(id)|
# +-------+
# |  250.5|
# +-------+

# %%
df.select('id').describe().show()
# Out:
# +-------+-----------------+
# |summary|               id|
# +-------+-----------------+
# |  count|              500|
# |   mean|            250.5|
# | stddev|144.4818327679989|
# |    min|                1|
# |    max|              500|
# +-------+-----------------+

# %%
df.describe().show()
# Out:
# 25/10/26 19:41:43 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +-------+-----------------+----------+---------+--------------------+----------+--------------+
# |summary|               id|first_name|last_name|               email|    gender|    ip_address|
# +-------+-----------------+----------+---------+--------------------+----------+--------------+
# |  count|              500|       500|      500|                 500|       500|           500|
# |   mean|            250.5|      NULL|     NULL|                NULL|      NULL|          NULL|
# | stddev|144.4818327679989|      NULL|     NULL|                NULL|      NULL|          NULL|
# |    min|                1|      Abbe|     Abry|abonifazio9r@tech...|   Agender|  0.184.57.108|
# |    max|              500|   Zsa zsa|   Ziehms|ztrightonaw@xinhu...|Polygender|99.158.211.248|
# ...

# %%
spark.stop()
